# %%
import pandas as pd
from pylab import *
from BrilReader import *
from BrilPlotter import *

# %matplotlib inline

# %%
col = ['runnum','lsnum','nbnum','bx']
df = BrilReader('../data/example.h5','bcm1futca_lumi_100_9', col)

# %%
plotBunchCrossingHistogram(df.loc[0],binsize=1)
plt.xlim(1000,1100)
# Out:
# (1000, 1100)

# %%
bx = np.array([df.bx]).reshape(-1,3564)

# %%
plt.figure(figsize=(10,3),facecolor='w')
plt.plot(bx[:,501])
plt.plot(bx[:,502])

# %%
list(h5py.File('../data/example.h5', 'r').keys())
# Out:
# ['bcm1futca_lumi_100_1',
#  'bcm1futca_lumi_100_10',
#  'bcm1futca_lumi_100_17',
#  'bcm1futca_lumi_100_18',
#  'bcm1futca_lumi_100_2',
#  'bcm1futca_lumi_100_33',
#  'bcm1futca_lumi_100_9',
#  'bcm1futca_lumi_101_1',
#  'bcm1futca_lumi_101_10',
#  'bcm1futca_lumi_101_17',
#  'bcm1futca_lumi_101_18',
#  'bcm1futca_lumi_101_2',
#  'bcm1futca_lumi_101_33',
#  'bcm1futca_lumi_101_9']

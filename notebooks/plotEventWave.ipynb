# %%
from pylab import *
import pandas as pd
from tb_EventWavePlotter import *
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5415ccf091cd> in <module>()
#       1 from pylab import *
#       2 import pandas as pd
# ----> 3 from tb_EventWavePlotter import *
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'tb_EventWavePlotter'

# %%
dataDir = "../data/eventWaves"
pt = EventWavePlotter(dataDir,"ubcm",loadNEvents=100)
pt.plotEventsHeatmap()
# Out:
# backend ubcm, wave lenth is 1600

# %%
pt.plotEvent(9)
pt.plotEvents()
